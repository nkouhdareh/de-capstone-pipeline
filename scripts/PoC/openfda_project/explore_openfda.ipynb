# %%
import pandas as pd

pd.__version__
# Out:
# '3.0.5'

# %%
import json
import pandas as pd

with open("data/raw/drug_event.json", "r", encoding="utf-8") as file:
    data = json.load(file)

records = data["results"]

df = pd.DataFrame(records)

df.head()
# Out:
#   safetyreportid transmissiondateformat transmissiondate serious  \
# 0      5801206-7                    102         20090109       1
# 1       10003300                    102         20141002       1
# 2       10003301                    102         20141002       1
# 3       10003302                    102         20141002       2
# 4       10003304                    102         20141212       2
#
#   seriousnessdeath receivedateformat receivedate receiptdateformat  \
# 0                1               102    20080707               102
# 1              NaN               102    20140306               102
# 2              NaN               102    20140228               102
# 3              NaN               102    20140312               102
# 4              NaN               102    20140312               102
#
#   receiptdate fulfillexpeditecriteria  ... safetyreportversion  \
# 0    20080625                       1  ...                 NaN
# 1    20140306                       2  ...                   1
# 2    20140228                       2  ...                   1
# 3    20140312                       2  ...                   1
# 4    20140424                       2  ...                   2
#
#   primarysourcecountry reporttype seriousnessdisabling duplicate  \
# 0                  NaN        NaN                  NaN       NaN
# 1                   US          1                    1         1
# 2                   US          1                  NaN         1
# 3                   US          1                  NaN         1
# 4                   US          1                  NaN         1
#
#                                      reportduplicate seriousnessother  \
# 0                                                NaN              NaN
# 1  {'duplicatesource': 'GENENTECH', 'duplicatenum...              NaN
# 2  {'duplicatesource': 'JANSSEN', 'duplicatenumb'...                1
# 3  {'duplicatesource': 'PFIZER', 'duplicatenumb':...              NaN
# 4  {'duplicatesource': 'PFIZER', 'duplicatenumb':...              NaN
#
#   occurcountry seriousnesshospitalization seriousnesslifethreatening
# 0          NaN                        NaN                        NaN
# 1          NaN                        NaN                        NaN
# 2          NaN                        NaN                        NaN
# 3           US                        NaN                        NaN
# 4           US                        NaN                        NaN
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (100, 25)

# %%
df.columns
# Out:
# Index(['safetyreportid', 'transmissiondateformat', 'transmissiondate',
#        'serious', 'seriousnessdeath', 'receivedateformat', 'receivedate',
#        'receiptdateformat', 'receiptdate', 'fulfillexpeditecriteria',
#        'companynumb', 'primarysource', 'sender', 'receiver', 'patient',
#        'safetyreportversion', 'primarysourcecountry', 'reporttype',
#        'seriousnessdisabling', 'duplicate', 'reportduplicate',
#        'seriousnessother', 'occurcountry', 'seriousnesshospitalization',
#        'seriousnesslifethreatening'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   safetyreportid              100 non-null    str
#  1   transmissiondateformat      100 non-null    str
#  2   transmissiondate            100 non-null    str
#  3   serious                     100 non-null    str
#  4   seriousnessdeath            4 non-null      str
#  5   receivedateformat           100 non-null    str
#  6   receivedate                 100 non-null    str
#  7   receiptdateformat           100 non-null    str
#  8   receiptdate                 100 non-null    str
#  9   fulfillexpeditecriteria     100 non-null    str
#  10  companynumb                 100 non-null    str
#  11  primarysource               100 non-null    object
#  12  sender                      100 non-null    object
#  13  receiver                    99 non-null     object
#  14  patient                     100 non-null    object
#  15  safetyreportversion         99 non-null     str
#  16  primarysourcecountry        99 non-null     str
#  17  reporttype                  99 non-null     str
#  18  seriousnessdisabling        2 non-null      str
#  19  duplicate                   99 non-null     str
#  20  reportduplicate             99 non-null     object
#  21  seriousnessother            14 non-null     str
#  22  occurcountry                97 non-null     str
#  23  seriousnesshospitalization  21 non-null     str
#  24  seriousnesslifethreatening  3 non-null      str
# dtypes: object(5), str(20)
# memory usage: 19.7+ KB

# %%
df["patient"].iloc[0]
# Out:
# {'patientonsetage': '26',
#  'patientonsetageunit': '801',
#  'patientsex': '1',
#  'patientdeath': {'patientdeathdateformat': None, 'patientdeathdate': None},
#  'reaction': [{'reactionmeddrapt': 'DRUG ADMINISTRATION ERROR'},
#   {'reactionmeddrapt': 'OVERDOSE'}],
#  'drug': [{'drugcharacterization': '1',
#    'medicinalproduct': 'DURAGESIC-100',
#    'drugauthorizationnumb': '019813',
#    'drugadministrationroute': '041',
#    'drugindication': 'DRUG ABUSE'}]}
